# %%
# Dependencies and Setup
import pandas as pd

import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine

# File to Load (Remember to Change These)
file_to_load = "./Resources/charts.csv"

# Read Purchasing File and store into Pandas data frame
billboard_df = pd.read_csv(file_to_load)

# %%
#billboard_df.dtypes
billboard_df
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# 2             Lil Nas X & Jack Harlow        3.0          1              14
# 3                        Walker Hayes        4.0          3              19
# 4                          Ed Sheeran        5.0          2              18
# ...                               ...        ...        ...             ...
# 330082                Thurston Harris        NaN         96               1
# 330083                Robert & Johnny        NaN         97               1
# 330084              The Ames Brothers        NaN         98               1
# 330085                 Billy Williams        NaN         99               1
# 330086                Frankie Vaughan        NaN        100               1
#
# [330087 rows x 7 columns]

# %%
billboard_new_df = billboard_df.copy()

#split the date by the - by year, month, day 
billboard_new_df[['Year', 'Month', 'Day']] = billboard_df['date'].str.split('-', expand=True)


#delete unessary columns 'date' and reorg the column order and reset index 
del billboard_new_df['date']

del billboard_new_df['last-week']

billboard_new_df.reset_index
billboard_new_df
# Out:
#         rank                                 song  \
# 0          1                           Easy On Me
# 1          2                                 Stay
# 2          3                        Industry Baby
# 3          4                           Fancy Like
# 4          5                           Bad Habits
# ...      ...                                  ...
# 330082    96                        Over And Over
# 330083    97                     I Believe In You
# 330084    98                      Little Serenade
# 330085    99  I'll Get By (As Long As I Have You)
# 330086   100                                 Judy
#
#                                artist  peak-rank  weeks-on-board  Year Month  \
# 0                               Adele          1               3  2021    11
# 1       The Kid LAROI & Justin Bieber          1              16  2021    11
# 2             Lil Nas X & Jack Harlow          1              14  2021    11
# 3                        Walker Hayes          3              19  2021    11
# 4                          Ed Sheeran          2              18  2021    11
# ...                               ...        ...             ...   ...   ...
# 330082                Thurston Harris         96               1  1958    08
# 330083                Robert & Johnny         97               1  1958    08
# 330084              The Ames Brothers         98               1  1958    08
# 330085                 Billy Williams         99               1  1958    08
# 330086                Frankie Vaughan        100               1  1958    08
#
#        Day
# 0       06
# 1       06
# 2       06
# 3       06
# 4       06
# ...     ..
# 330082  04
# 330083  04
# 330084  04
# 330085  04
# 330086  04
#
# [330087 rows x 8 columns]

# %%
#rename the columns so they are upper case
billboard_new_df = billboard_new_df.rename(columns={'rank': 'Rank', 'song': 'Song', 'artist': 'Artist', 'peak-rank': 'Peak-Rank', 'weeks-on-board': 'Weeks-On-Board'})

#reorder columns 
billboard_new_df_update = billboard_new_df[['Rank', 'Song', 'Artist','Peak-Rank', 'Weeks-On-Board','Month', 'Day', 'Year']]
# billboard_new_df = billboard_df.reset_index()
billboard_new_df_update

#fill in NaN on entire database 
billboard_new_df_update.fillna(0)


#turn month, day, year into an integer from an object 
billboard_new_df_update[['Month', 'Day', 'Year']] = billboard_new_df_update[['Month', 'Day', 'Year']].astype('int')

# %%
billboard_new_df_update.dtypes
# Out:
# Rank               int64
# Song              object
# Artist            object
# Peak-Rank          int64
# Weeks-On-Board     int64
# Month              int64
# Day                int64
# Year               int64
# dtype: object

# %%
#filter for since the year 2020 
billboard_filtered_df = billboard_new_df_update.loc[(billboard_new_df_update['Year']>=2020) & (billboard_new_df_update['Rank'] <= 10)]



billboard_filtered_df.reset_index
billboard_filtered_df
# Out:
#       Rank                                      Song  \
# 0        1                                Easy On Me
# 1        2                                      Stay
# 2        3                             Industry Baby
# 3        4                                Fancy Like
# 4        5                                Bad Habits
# ...    ...                                       ...
# 9605     6                                   Roxanne
# 9606     7  It's The Most Wonderful Time Of The Year
# 9607     8                         Someone You Loved
# 9608     9                                  Memories
# 9609    10                              Good As Hell
#
#                              Artist  Peak-Rank  Weeks-On-Board  Month  Day  \
# 0                             Adele          1               3     11    6
# 1     The Kid LAROI & Justin Bieber          1              16     11    6
# 2           Lil Nas X & Jack Harlow          1              14     11    6
# 3                      Walker Hayes          3              19     11    6
# 4                        Ed Sheeran          2              18     11    6
# ...                             ...        ...             ...    ...  ...
# 9605                 Arizona Zervas          4               8      1    4
# 9606                  Andy Williams          7              15      1    4
# 9607                  Lewis Capaldi          1              33      1    4
# 9608                       Maroon 5          4              14      1    4
# 9609                          Lizzo          3              18      1    4
#
#       Year
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 9605  2020
# 9606  2020
# 9607  2020
# 9608  2020
# 9609  2020
#
# [970 rows x 8 columns]

# %%
billboard_filtered_df

engine = create_engine("sqlite:///Country.sqlite")
billboard_filtered_df.to_sql(name="country_USA", con=engine, if_exists="append", index=False)
# pd.read_sql_query("select * from country_USA", con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#
# OperationalError: table country_USA has no column named Peak-Rank
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/b9/m6ntk1l94mj0xc_5wxrc4dc40000gn/T/ipykernel_78308/4123740679.py in <module>
#       2
#       3 engine = create_engine("sqlite:///Country.sqlite")
# ----> 4 billboard_filtered_df.to_sql(name="country_USA", con=engine, if_exists="append", index=False)
#       5 # pd.read_sql_query("select * from country_USA", con=engine).head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     712
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
#
# OperationalError: (sqlite3.OperationalError) table country_USA has no column named Peak-Rank
# [SQL: INSERT INTO "country_USA" ("Rank", "Song", "Artist", "Peak-Rank", "Weeks-On-Board", "Month", "Day", "Year") VALUES (?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ((1, 'Easy On Me', 'Adele', 1, 3, 11, 6, 2021), (2, 'Stay', 'The Kid LAROI & Justin Bieber', 1, 16, 11, 6, 2021), (3, 'Industry Baby', 'Lil Nas X & Jack Harlow', 1, 14, 11, 6, 2021), (4, 'Fancy Like', 'Walker Hayes', 3, 19, 11, 6, 2021), (5, 'Bad Habits', 'Ed Sheeran', 2, 18, 11, 6, 2021), (6, 'Way 2 Sexy', 'Drake Featuring Future & Young Thug', 1, 8, 11, 6, 2021), (7, 'Shivers', 'Ed Sheeran', 7, 7, 11, 6, 2021), (8, 'Good 4 U', 'Olivia Rodrigo', 1, 24, 11, 6, 2021)  ... displaying 10 of 970 total bound parameter sets ...  (9, 'Memories', 'Maroon 5', 4, 14, 1, 4, 2020), (10, 'Good As Hell', 'Lizzo', 3, 18, 1, 4, 2020))]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
